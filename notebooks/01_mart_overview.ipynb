# %% [markdown]
# # Mart overview
#
# Ceres AI starter — `data/mart/modeling_mart.csv`

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from ceres_ai.data import load_mart, summarize
df = load_mart()
print(summarize())
df.head()

# %%
df["yield_source"].value_counts(dropna=False)
